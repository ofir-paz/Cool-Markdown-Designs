# %% [markdown]
# <style>
# .note-box {
#     border-left: 4px solid #0078D4;
#     border-image: 1;
#     padding-left: 10px;
#     border-radius: 0px;
#     padding-top: 2px;
#     padding-bottom: 2px;
# }
# .note-header {
#     display: flex;
#     align-items: center;
#     padding-bottom: 0.3em;
# }
# .note-icon {
#     font-size: 14px;
#     color: #0078D4;
#     background-color: #1E1E1E;
#     border: 2px solid #0078D4;
#     border-radius: 100%;
#     width: 16px;
#     height: 16px;
#     display: flex;
#     align-items: center;
#     justify-content: center;
#     margin-right: 8px;
# }
# .note {
#     color: #0078D4;
#     font-weight: bold;
# }
# .note-content {
# }
# </style>
#
# <blockquote class="note-box">
#  <div class="note-header">
#   <span class="note-icon">ℹ️</span><strong class="note">Note</strong>
#  </div>
#   <span class="note-content">Hello, this is a beautifully styled note with rounded corners.</span>
# </blockquote>

# %% [markdown]
# <style>
# .note-box {
#     border-left: 4px solid #0078D4;
#     color: #D4D4D4;
#     font-family: sans-serif;
#     padding-left: 10px;
# }
#
# .note-header {
#     display: flex;
#     align-items: center; /* Aligns icon and title vertically */
#     margin-bottom: 15px; /* Adds space between header and content */
# }
#
# .note-title {
#     color: #0078D4;
#     font-weight: bold;
#     display: inline-block;
# }
#
# .note-icon {
#     font-size: 14px;
#     color: #0078D4;
#     background-color: #1E1E1E;
#     border: 2px solid #0078D4;
#     border-radius: 100%;
#     width: 15px;
#     height: 15px;
#     display: flex;
#     align-items: center;
#     justify-content: center;
#     margin-right: 8px;
# }
#
# .note-content {
#     padding-left: 5px;
#     font-family: Arial;
# }
# </style>
#
# <blockquote class="note-box">
#     <div class="note-header">
#         <span class="note-icon">ℹ️</span>
#         <strong class="note-title">Note</strong>
#     </div>
#     <span>For further reading about MRI sequences and the specifics of the parameters used to configure one, you can read <a href="https://radiopaedia.org/articles/mri-sequence-parameters?lang=us">this article</a>.</span>
# </blockquote>

# %% [markdown]
# <blockquote style="border-left: 5px solid; border-image: linear-gradient(to bottom, #00f, #0ff) 1; padding-left: 10px; background-color: #f0f8ff;">
#   <span style="color: #1e90ff; font-weight: bold;">Note</span> <br>
#   <span style="color: #696969;">Hello, this is a beautifully styled note with a background color.</span>
# </blockquote>

# %% [markdown]
# <blockquote style="border-left: 5px solid; border-image: linear-gradient(to bottom, #00f, #0ff) 1; padding-left: 10px; font-family: 'Courier New', Courier, monospace;">
#   <span style="color: #1e90ff; font-weight: bold;">Note</span> <br>
#   <span style="color: #696969;">Hello, this is a beautifully styled note with a custom font.</span>
# </blockquote>

# %% [markdown]
# <blockquote style="border-left: 5px solid; border-image: linear-gradient(to bottom, #00f, #0ff) 1; padding-left: 10px; box-shadow: 2px 2px 12px rgba(0, 0, 0, 0.1); border-radius: 10px; background-color: #f0f8ff; font-family: 'Courier New', Courier, monospace;">
#   <span style="color: #1e90ff; font-weight: bold;">Note</span> <br>
#   <span style="color: #696969;">Hello, this is a beautifully styled note with all the customizations applied.</span>
# </blockquote>

# %% [markdown]
# <details>
#   <summary>1. Click to expand!</summary>
#
#   1. Item 1
#   2. Item 2
#   3. Item 3
# </details>

# %% [markdown]
# <table>
#   <tr>
#     <th style="background-color: #4CAF50; color: white;">Header 1</th>
#     <th style="background-color: #4CAF50; color: white;">Header 2</th>
#   </tr>
#   <tr>
#     <td>Row 1, Cell 1</td>
#     <td>Row 1, Cell 2</td>
#   </tr>
#   <tr>
#     <td>Row 2, Cell 1</td>
#     <td>Row 2, Cell 2</td>
#   </tr>
# </table>

# %% [markdown]
# # Welcome to My Notebook! 🎉
#
# Here are some cool features:
# - Easy to use ✅
# - Highly customizable 🎨
# - Supports many languages 🌍

# %% [markdown]
# <span style="background-color: #4CAF50; color: white; padding: 5px; border-radius: 5px;">New</span>
#
# I am crazy!

# %% [markdown]
# <div style="border: 2px solid #4CAF50; padding: 10px; border-radius: 5px;">
#   <h2 style="color: #4CAF50;">Custom Styled Box</h2>
#   <p>This is a box with custom styling using HTML and CSS.</p>
# </div>

# %% [markdown]
# <style>
# @keyframes slideIn {
#   from {
#     transform: translateX(-100%);
#   }
#   to {
#     transform: translateX(0);
#   }
# }
# .animated-text {
#   display: inline-block;
#   animation: slideIn 2s ease-out;
# }
# </style>
#
# <span class="animated-text">This text slides in from the left!</span>

# %% [markdown]
# <style>
# @keyframes rotate {
#   from {
#     transform: rotate(0deg);
#   }
#   to {
#     transform: rotate(360deg);
#   }
# }
# .rotating-element {
#   display: inline-block;
#   animation: rotate 4s linear infinite;
# }
# </style>
#
# <span class="rotating-element">🔄</span>

# %% [markdown]
# <style>
# .progress-bar {
#   width: 100%;
#   background-color: #f3f3f3;
#   border-radius: 5px;
#   overflow: hidden;
# }
# .progress-bar-inner {
#   width: 70%;
#   height: 20px;
#   background-color: #4CAF50;
#   text-align: center;
#   line-height: 20px;
#   color: white;
# }
# </style>
#
# <div class="progress-bar">
#   <div class="progress-bar-inner">70%</div>
# </div>

# %% [markdown]
# <style>
# .custom-checkbox {
#   display: inline-block;
#   width: 20px;
#   height: 20px;
#   background: #4CAF50;
#   border-radius: 3px;
#   position: relative;
# }
# .custom-checkbox input {
#   opacity: 0;
#   width: 20px;
#   height: 20px;
#   position: absolute;
#   cursor: pointer;
# }
# .custom-checkbox input:checked + .checkmark {
#   display: block;
# }
# .checkmark {
#   display: none;
#   position: absolute;
#   top: 2px;
#   left: 6px;
#   width: 6px;
#   height: 12px;
#   border: solid white;
#   border-width: 0 2px 2px 0;
#   transform: rotate(45deg);
# }
# </style>
#
# <label class="custom-checkbox">
#   <input type="checkbox">
#   <span class="checkmark"></span>
# </label>

# %% [markdown]
# <style>
# .alert {
#   padding: 20px;
#   background-color: #f44336;
#   color: white;
#   margin-bottom: 15px;
#   border-radius: 5px;
# }
# .alert.success {background-color: #4CAF50;}
# .alert.info {background-color: #2196F3;}
# .alert.warning {background-color: #ff9800;}
# </style>
#
# <div class="alert">
#   This is a red alert box.
# </div>
#
# <div class="alert success">
#   This is a green success box.
# </div>
#
# <div class="alert info">
#   This is a blue info box.
# </div>
#
# <div class="alert warning">
#   This is an orange warning box.
# </div>

# %% [markdown]
# <style>
# .carousel {
#   display: flex;
#   overflow: hidden;
#   width: 300px;
#   border: 1px solid #ddd;
#   border-radius: 5px;
# }
# .carousel img {
#   width: 300px;
#   transition: transform 0.5s ease;
# }
# </style>
#
# <div class="carousel">
#   <img src="https://www.nintendo.co.il/wp-content/uploads/2021/05/Untitled-3.png" alt="Image 1">
#   <img src="https://via.placeholder.com/300x200?text=Image+2" alt="Image 2">
#   <img src="https://via.placeholder.com/300x200?text=Image+3" alt="Image 3">
# </div>
#
# <script>
# let index = 0;
# const images = document.querySelectorAll('.carousel img');
# setInterval(() => {
#   index = (index + 1) % images.length;
#   images.forEach((img, i) => {
#     img.style.transform = `translateX(${-index * 300}px)`;
#   });
# }, 2000);
# </script>

# %% [markdown]
# <style>
# .custom-button {
#   background-color: #4CAF50;
#   border: none;
#   color: white;
#   padding: 15px 32px;
#   text-align: center;
#   text-decoration: none;
#   display: inline-block;
#   font-size: 16px;
#   margin: 4px 2px;
#   cursor: pointer;
#   border-radius: 12px;
#   transition: background-color 0.3s;
# }
# .custom-button:hover {
#   background-color: #45a049;
# }
# </style>
#
# <button class="custom-button">Custom Button</button>

# %% [markdown]
# <style>
# @keyframes move {
#   0% { transform: translateY(0); }
#   100% { transform: translateY(-1000px); }
# }
# .particle {
#   position: absolute;
#   width: 5px;
#   height: 5px;
#   background: white;
#   border-radius: 50%;
#   animation: move 10s linear infinite;
# }
# .particle:nth-child(2) { left: 20%; animation-duration: 12s; }
# .particle:nth-child(3) { left: 40%; animation-duration: 14s; }
# .particle:nth-child(4) { left: 60%; animation-duration: 16s; }
# .particle:nth-child(5) { left: 80%; animation-duration: 18s; }
# </style>
#
# <div style="position: relative; height: 200px; background: black; overflow: hidden;">
#   <div class="particle"></div>
#   <div class="particle"></div>
#   <div class="particle"></div>
#   <div class="particle"></div>
#   <div class="particle"></div>
#   <div style="position: relative; color: white; text-align: center; padding-top: 80px;">
#     Particle Background Effect
#   </div>
# </div>

# %% [markdown]
# <style>
# .shape {
#   width: 100px;
#   height: 100px;
#   background-color: #4CAF50;
#   margin: 20px;
#   display: inline-block;
# }
# .circle {
#   border-radius: 50%;
# }
# .triangle {
#   width: 0;
#   height: 0;
#   border-left: 50px solid transparent;
#   border-right: 50px solid transparent;
#   border-bottom: 100px solid #4CAF50;
# }
# </style>
#
# <div class="shape"></div>
# <div class="shape circle"></div>
# <div class="shape triangle"></div>

# %% [markdown]
# <style>
# @keyframes bounce {
#   0%, 20%, 50%, 80%, 100% { transform: translateY(0); }
#   40% { transform: translateY(-150px); }
#   60% { transform: translateY(-75px); }
# }
# .bouncing-ball {
#   width: 50px;
#   height: 50px;
#   background-color: #4CAF50;
#   border-radius: 50%;
#   position: relative;
#   animation: bounce 2s infinite;
# }
# </style>
#
# <div class="bouncing-ball"></div>

# %% [markdown]
# <style>
# .hover-effect img {
#   transition: transform 0.3s;
# }
# .hover-effect img:hover {
#   transform: scale(1.1);
# }
# </style>
#
# <div class="hover-effect">
#   <img src="https://via.placeholder.com/150" alt="Hover Image">
# </div>

# %% [markdown]
# <style>
# .accordion {
#   background-color: #eee;
#   color: #444;
#   cursor: pointer;
#   padding: 18px;
#   width: 100%;
#   border: none;
#   text-align: left;
#   outline: none;
#   font-size: 15px;
#   transition: 0.4s;
# }
# .active, .accordion:hover {
#   background-color: #ccc;
# }
# .panel {
#   padding: 0 18px;
#   display: none;
#   background-color: white;
#   overflow: hidden;
# }
# </style>
#
# <button class="accordion">Section 1</button>
# <div class="panel">
#   <p>Content for section 1.</p>
# </div>
#
# <button class="accordion">Section 2</button>
# <div class="panel">
#   <p>Content for section 2.</p>
# </div>
#
# <script>
# var acc = document.getElementsByClassName("accordion");
# for (var i = 0; i < acc.length; i++) {
#   acc[i].onclick = function() {
#     this.classList.toggle("active");
#     var panel = this.nextElementSibling;
#     if (panel.style.display === "block") {
#       panel.style.display = "none";
#     } else {
#       panel.style.display = "block";
#     }
#   }
# }
# </script>

# %% [markdown]
# <style>
# .spinner {
#   border: 16px solid #f3f3f3;
#   border-top: 16px solid #3498db;
#   border-radius: 50%;
#   width: 120px;
#   height: 120px;
#   animation: spin 2s linear infinite;
# }
# @keyframes spin {
#   0% { transform: rotate(0deg); }
#   100% { transform: rotate(360deg); }
# }
# </style>
#
# <div class="spinner"></div>

# %% [markdown]
# <style>
# .beautiful-text {
#   font-size: 20px;
#   font-weight: bold;
#   color: #ff6347; /* Tomato */
#   background-color: #f0e68c; /* Khaki */
#   padding: 10px;
#   border-radius: 5px;
#   text-align: center;
# }
# </style>
#
# <div class="beautiful-text">
#   Ofir the King!!!
# </div>

# %% [markdown]
# # Welcome to the Video! 🎉
#
# Here are some cool features in the video:
# - Easy to use ✅
# - Muscles 💪
# - Supports many languages 🌍
# - Muffin is the best 🧁

# %% [markdown]
# <iframe width="560" height="315" src="https://www.youtube.com/embed/2Nm_BNvAZ0I" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
